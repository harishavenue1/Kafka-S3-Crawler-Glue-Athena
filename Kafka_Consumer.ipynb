# %%
# !pip install s3fs
# Out:
# ...
#   Using cached botocore-1.29.76-py3-none-any.whl (10.4 MB)
# ...
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.27.96
#     Uninstalling botocore-1.27.96:
#       Successfully uninstalled botocore-1.27.96
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# boto3 1.24.28 requires botocore<1.28.0,>=1.27.28, but you have botocore 1.29.76 which is incompatible.

# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'demo_testing2',
     bootstrap_servers=['43.205.192.154:9092'], #add your IP here
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
# for c in consumer:
#     print(c.value)

# %%
s3 = S3FileSystem(anon=False, key='AKIA2YU6DYZWEHR3JRPH', secret='TcFUqd/PFQ1eau3aSqBJxBSefFTFae1H9jtpM4Qd')

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://kafka-stock-market-data-harish/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
        print('wrote',i.value)
# Out:
# wrote {'Index': 'GDAXI', 'Date': '2001-09-11', 'Open': 4680.799805, 'High': 4788.379883, 'Low': 4130.52002, 'Close': 4273.529785, 'Adj Close': 4273.529785, 'Volume': 119871600.0, 'CloseUSD': 5213.7063377}
# wrote {'Index': '399001.SZ', 'Date': '2001-05-18', 'Open': 4858.100098, 'High': 4867.140137, 'Low': 4836.569824, 'Close': 4865.72998, 'Adj Close': 4865.675781, 'Volume': 0.0, 'CloseUSD': 778.5167968000001}
# wrote {'Index': 'N225', 'Date': '1993-08-31', 'Open': 20924.58984, 'High': 21029.69922, 'Low': 20831.08008, 'Close': 21026.59961, 'Adj Close': 21026.59961, 'Volume': 0.0, 'CloseUSD': 210.2659961}
# wrote {'Index': 'NYA', 'Date': '1979-02-23', 'Open': 580.289978, 'High': 580.289978, 'Low': 580.289978, 'Close': 580.289978, 'Adj Close': 580.289978, 'Volume': 0.0, 'CloseUSD': 580.289978}
# ...
